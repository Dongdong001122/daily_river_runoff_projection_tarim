# %%
import numpy as np
import pandas as pd
import os
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
from scipy.stats import pearsonr

# %%
def nse(y_true, y_pred):
    return 1 - (np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
import numpy as np

def pbias(y_true, y_pred):
    pbias_value = 100 * np.sum(y_true - y_pred) / np.sum(y_true)
    return float(pbias_value)


def kge(y_true, y_pred):
    # Calculate the Pearson correlation coefficient (r)
    r, _ = pearsonr(y_true, y_pred)
    
    # Calculate the mean of the observed and predicted values
    mu_true = np.mean(y_true)
    mu_pred = np.mean(y_pred)
    
    # Calculate the standard deviation of the observed and predicted values
    sigma_true = np.std(y_true)
    sigma_pred = np.std(y_pred)
    
    # Compute the KGE
    kge_value = 1 - np.sqrt((r - 1)**2 + (sigma_pred / sigma_true - 1)**2 + (mu_pred / mu_true - 1)**2)
    
    return kge_value

# %%
# Set working directory and load the dataset
os.chdir('F:\\geodata\\river_runoff_obs')

# %%
GCM_name = 'MRI-ESM2-0'
'multi-model'
'BCC-CSM2-MR'
'MRI-ESM2-0'
'INM-CM5-0'
'INM-CM4-8'
input_file_name_list = ['1_hsg_imputMF','2_dsk_imputMF','3_xhl_imputMF','4_slglk_imputMF','5_kq_imputMF','6_wlwt_imputMF','7_tgzlk_imputMF']

# %%
from datetime import datetime# Get current time
current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
# 创建文件名
txtbook_path = f'F:\\geodata\\river_runoff_obs\\note\\note_XGBoost_{GCM_name}_{current_time}_mon.txt'
print(txtbook_path)

for input_file_name in input_file_name_list:
    abbre = input_file_name.split('_')[1]
    for scenario in ['ssp126','ssp245','ssp370','ssp585']:
        print(scenario)
        name = f'{input_file_name}_{GCM_name}_{scenario}_r1i1p1f1_mon'
        csv_path = f"{name}.csv"     
        data = pd.read_csv(csv_path)
        
        # Check the structure of the data
        print(data.head())
        print(data.info())
            
        # Add 1-month lag features
        data['pre_lag1'] = data['pre'].shift(1)
        data['tm_lag1'] = data['tm'].shift(1)
        data['gr_lag1'] = data['gr'].shift(1)
        
        # Drop rows with NaN values resulting from shifting
        data = data.dropna()
        
        # Select input features and target for runoff prediction
        X_runoff = data[['pre', 'tm', 'gr', 'pre_lag1', 'tm_lag1', 'gr_lag1']]
        y_runoff = data['dis']
        
        # Select input features and target for evaporation prediction
        y_evaporation = data['ep']
            
        
        # Split the data for both runoff and evaporation models
        X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(X_runoff, y_runoff, test_size=0.2, random_state=42)
        X_train_e, X_test_e, y_train_e, y_test_e = train_test_split(X_runoff, y_evaporation, test_size=0.2, random_state=42)
        
        # Initialize and train the models
        model_runoff = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
        model_runoff.fit(X_train_r, y_train_r)
        model_evaporation = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
        model_evaporation.fit(X_train_e, y_train_e)
        
        # Predict and evaluate both models
        y_pred_runoff = model_runoff.predict(X_test_r)
        y_pred_evaporation = model_evaporation.predict(X_test_e)
        rmse_runoff = root_mean_squared_error(y_test_r, y_pred_runoff)
        rmse_evaporation = root_mean_squared_error(y_test_e, y_pred_evaporation)
        
        print(f"Runoff RMSE: {rmse_runoff}")
        print(f"Evaporation RMSE: {rmse_evaporation}")
        
        # Calculate NSE for runoff and evaporation
        nse_runoff = nse(y_test_r, y_pred_runoff)
        kge_runoff = kge(y_test_r, y_pred_runoff)
        pbias_runoff = pbias(y_test_r, y_pred_runoff)
        
        print('nse_runoff:',nse_runoff,'nse_ep:',nse_evaporation,'kge_runoff:',kge_runoff,'pbias_runoff:',pbias_runoff)
        nse_runoff = nse(y_test_r, y_pred_runoff)
        nse_evaporation = nse(y_test_e, y_pred_evaporation)
        print(f"Runoff NSE: {nse_runoff}")
        print(f"Evaporation NSE: {nse_evaporation}")
            
        # Prepare future data inputs (remove 'dis' and 'ep' columns if they exist)
        future_data = pd.read_csv(csv_path)
        # Add 1-month lag features
        future_data['pre_lag1'] = future_data['pre'].shift(1)
        future_data['tm_lag1'] = future_data['tm'].shift(1)
        future_data['gr_lag1'] = future_data['gr'].shift(1)
        # future_data = data[data['dis'].isna() | data['ep'].isna()]
        X_future = future_data[['pre', 'tm', 'gr', 'pre_lag1', 'tm_lag1', 'gr_lag1']]
        
        # Predict future runoff and evaporation
        future_data['runoff_projection'] = model_runoff.predict(X_future)
        future_data['evaporation_projection'] = model_evaporation.predict(X_future)
        
        print(future_data[['time', 'runoff_projection', 'evaporation_projection']])  # Display future projections
            
        future_data.to_csv(f'XGBoost_mon\\{name}_project.csv')
        # Concatenate historical and future data
        historic_data = data.dropna(subset=['dis', 'ep'])
        combined_data = pd.concat([historic_data, future_data])
        
        # Convert the 'time' column to datetime format and set it as the index
        combined_data['time'] = pd.to_datetime(combined_data['time'], format='%Y/%m/%d', errors='coerce')
        combined_data = combined_data.dropna(subset=['time'])  # Drop any rows with invalid 'time'
        combined_data.set_index('time', inplace=True)
        
        # Display the updated DataFrame
        print(combined_data.head())
        future_data[['dis', 'runoff_projection', 'ep', 'evaporation_projection']].plot(title="Runoff and Evaporation Projections")
        
        # append the information at the end of text book
        with open(txtbook_path, 'a') as file:
            file.write(f"Name: {name}, Scenario: {scenario},NSE Runoff: {nse_runoff}, KGE Runoff: {kge_runoff},Pbias Runoff: {pbias_runoff}\n")
# Out:
# F:\geodata\river_runoff_obs\note\note_XGBoost_MRI-ESM2-0_2024-12-15_12-09-33_mon.txt
# ssp126
#          time       dis          tm       pre          ep        ep.1  \
# 0  2000-01-01  6.029355  259.816131  0.000007    7.161290    7.161290
# 1  2000-02-01  6.117931  263.568475  0.000014   33.724138   33.724138
# 2  2000-03-01  5.010000  267.931313  0.000012   84.322581   84.322581
# 3  2000-04-01  4.896667  277.609166  0.000022   98.000000   98.000000
# 4  2000-05-01  9.342903  282.779926  0.000068  146.741935  146.741935
#
#            gr        tm.1     pre.1
# 0    0.000000  259.816131  0.000007
# 1    0.000000  263.568475  0.000014
# 2    0.000000  267.931313  0.000012
# 3    0.000000  277.609166  0.000022
# 4  487.663232  282.779926  0.000068
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     204 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 8.23752496801868
# Evaporation RMSE: 22.17607613073333
# nse_runoff: 0.30340567350051895 nse_ep: 0.9552316500498582 kge_runoff: 0.6668895830286914 pbias_runoff: -6.9563179182838395
# Runoff NSE: 0.30340567350051895
# Evaporation NSE: 0.9469318159484599
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          26.834944               29.066814
# 1     2000-02-01           4.582901               34.641853
# 2     2000-03-01           4.740552               53.521812
# 3     2000-04-01           4.740552               91.075157
# 4     2000-05-01           9.309701              152.701584
# ...          ...                ...                     ...
# 1207  2100-08-01          22.809986              125.436707
# 1208  2100-09-01          11.865321              108.083649
# 1209  2100-10-01           8.088903               49.547089
# 1210  2100-11-01           5.758485               48.974827
# 1211  2100-12-01           4.693699               11.591572
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp245
#          time       dis          tm       pre          ep        ep.1  \
# 0  2000-01-01  6.029355  259.816131  0.000007    7.161290    7.161290
# 1  2000-02-01  6.117931  263.568475  0.000014   33.724138   33.724138
# 2  2000-03-01  5.010000  267.931313  0.000012   84.322581   84.322581
# 3  2000-04-01  4.896667  277.609166  0.000022   98.000000   98.000000
# 4  2000-05-01  9.342903  282.779926  0.000068  146.741935  146.741935
#
#           gr        tm.1     pre.1
# 0   0.000000  259.816131  0.000007
# 1   0.000000  263.568475  0.000014
# 2   0.000000  267.931313  0.000012
# 3   0.000000  277.609166  0.000022
# 4  22.938519  282.779926  0.000068
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     204 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 8.28237152861564
# Evaporation RMSE: 22.867538548079025
# nse_runoff: 0.29580025864817727 nse_ep: 0.9469318159484599 kge_runoff: 0.6640912933754488 pbias_runoff: -1.6881534661529658
# Runoff NSE: 0.29580025864817727
# Evaporation NSE: 0.9435708304876875
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          13.572254               11.753134
# 1     2000-02-01           4.800828               32.252342
# 2     2000-03-01           4.709738               65.535301
# 3     2000-04-01           4.927554               95.415985
# 4     2000-05-01           9.888434              153.342529
# ...          ...                ...                     ...
# 1207  2100-08-01          28.782568              160.614563
# 1208  2100-09-01          22.614616              125.166580
# 1209  2100-10-01          10.888860               65.688339
# 1210  2100-11-01           5.585089               31.114744
# 1211  2100-12-01           4.717893                9.111933
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp370
#          time       dis          tm       pre          ep        ep.1  \
# 0  2000-01-01  6.029355  259.816131  0.000007    7.161290    7.161290
# 1  2000-02-01  6.117931  263.568475  0.000014   33.724138   33.724138
# 2  2000-03-01  5.010000  267.931313  0.000012   84.322581   84.322581
# 3  2000-04-01  4.896667  277.609166  0.000022   98.000000   98.000000
# 4  2000-05-01  9.342903  282.779926  0.000068  146.741935  146.741935
#
#             gr        tm.1     pre.1
# 0     0.000000  259.816131  0.000007
# 1     0.000000  263.568475  0.000014
# 2     0.000000  267.931313  0.000012
# 3     0.000000  277.609166  0.000022
# 4  1346.688184  282.779926  0.000068
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     204 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 5.947895400462539
# Evaporation RMSE: 21.405342193376203
# nse_runoff: 0.6368273877044773 nse_ep: 0.9435708304876875 kge_runoff: 0.8134503171565831 pbias_runoff: 2.699957342394294
# Runoff NSE: 0.6368273877044773
# Evaporation NSE: 0.9505565042100104
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          14.265397               21.615353
# 1     2000-02-01           4.692079               33.444000
# 2     2000-03-01           4.627182               58.742828
# 3     2000-04-01           4.692103              106.038620
# 4     2000-05-01           8.557464              148.945236
# ...          ...                ...                     ...
# 1207  2100-08-01          29.215902              149.066925
# 1208  2100-09-01          30.450527              154.165161
# 1209  2100-10-01          11.174280               51.343845
# 1210  2100-11-01           6.395880               51.804108
# 1211  2100-12-01           4.753500               13.397839
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp585
#          time       dis          tm       pre          ep        ep.1  \
# 0  2000-01-01  6.029355  259.816131  0.000007    7.161290    7.161290
# 1  2000-02-01  6.117931  263.568475  0.000014   33.724138   33.724138
# 2  2000-03-01  5.010000  267.931313  0.000012   84.322581   84.322581
# 3  2000-04-01  4.896667  277.609166  0.000022   98.000000   98.000000
# 4  2000-05-01  9.342903  282.779926  0.000068  146.741935  146.741935
#
#            gr        tm.1     pre.1
# 0    0.000000  259.816131  0.000007
# 1    0.000000  263.568475  0.000014
# 2    0.000000  267.931313  0.000012
# 3    0.000000  277.609166  0.000022
# 4  403.242362  282.779926  0.000068
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     204 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 7.816095678910355
# Evaporation RMSE: 23.282780454460408
# nse_runoff: 0.3728575775907478 nse_ep: 0.9505565042100104 kge_runoff: 0.690274507857745 pbias_runoff: -10.563547228509789
# Runoff NSE: 0.3728575775907478
# Evaporation NSE: 0.9415028773042731
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          12.572876               22.095661
# 1     2000-02-01           4.708979               32.505466
# 2     2000-03-01           4.651679               61.451199
# 3     2000-04-01           4.849300               96.400230
# 4     2000-05-01          10.581857              150.686096
# ...          ...                ...                     ...
# 1207  2100-08-01          20.651443              188.925049
# 1208  2100-09-01          14.949422              124.487793
# 1209  2100-10-01          11.736402              114.086433
# 1210  2100-11-01           6.643466               52.468647
# 1211  2100-12-01           5.436644               13.781277
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp126
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   77.958065  256.847377  0.000010    3.899194    3.899194
# 1  2000-02-01   60.334483  260.237813  0.000016    6.876437    6.876437
# 2  2000-03-01   63.800000  264.383167  0.000015   30.002688   30.002688
# 3  2000-04-01  131.486667  274.298624  0.000039  135.943056  135.943056
# 4  2000-05-01  158.903226  279.958319  0.000069  210.940860  210.940860
#
#               gr        tm.1     pre.1
# 0       0.000000  256.847377  0.000010
# 1       0.000000  260.237813  0.000016
# 2       0.000000  264.383167  0.000015
# 3       0.000000  274.298624  0.000039
# 4  259789.231798  279.958319  0.000069
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     229 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 43.389046971378676
# Evaporation RMSE: 16.345019256622393
# nse_runoff: 0.7236235025198983 nse_ep: 0.9415028773042731 kge_runoff: 0.8448184596699727 pbias_runoff: -2.0642110475279964
# Runoff NSE: 0.7236235025198983
# Evaporation NSE: 0.9792674332862258
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         157.972900                7.904243
# 1     2000-02-01          58.653423                6.134510
# 2     2000-03-01          56.488964               26.657650
# 3     2000-04-01         117.694939              142.898361
# 4     2000-05-01         150.633087              212.630249
# ...          ...                ...                     ...
# 1207  2100-08-01         169.282516              264.095795
# 1208  2100-09-01         164.040802              142.571747
# 1209  2100-10-01          98.807846               53.793583
# 1210  2100-11-01          75.707825               18.420092
# 1211  2100-12-01          56.564007                5.749691
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp245
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   77.958065  256.847377  0.000010    3.899194    3.899194
# 1  2000-02-01   60.334483  260.237813  0.000016    6.876437    6.876437
# 2  2000-03-01   63.800000  264.383167  0.000015   30.002688   30.002688
# 3  2000-04-01  131.486667  274.298624  0.000039  135.943056  135.943056
# 4  2000-05-01  158.903226  279.958319  0.000069  210.940860  210.940860
#
#               gr        tm.1     pre.1
# 0       0.000000  256.847377  0.000010
# 1       0.000000  260.237813  0.000016
# 2       0.000000  264.383167  0.000015
# 3       0.000000  274.298624  0.000039
# 4  197039.040751  279.958319  0.000069
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     229 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 43.03441340011127
# Evaporation RMSE: 16.43275270066284
# nse_runoff: 0.7281228795149057 nse_ep: 0.9792674332862258 kge_runoff: 0.8541515635363198 pbias_runoff: -6.042571726424838
# Runoff NSE: 0.7281228795149057
# Evaporation NSE: 0.979044267914779
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         124.594437                9.351842
# 1     2000-02-01          56.494083                7.329915
# 2     2000-03-01          58.241138               20.721863
# 3     2000-04-01         113.509819              137.622467
# 4     2000-05-01         161.299850              209.349838
# ...          ...                ...                     ...
# 1207  2100-08-01         253.382126              264.579712
# 1208  2100-09-01         172.537430              191.311737
# 1209  2100-10-01         117.487938               60.173019
# 1210  2100-11-01         104.348419               24.777523
# 1211  2100-12-01          69.963272                2.488466
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp370
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   77.958065  256.847377  0.000010    3.899194    3.899194
# 1  2000-02-01   60.334483  260.237813  0.000016    6.876437    6.876437
# 2  2000-03-01   63.800000  264.383167  0.000015   30.002688   30.002688
# 3  2000-04-01  131.486667  274.298624  0.000039  135.943056  135.943056
# 4  2000-05-01  158.903226  279.958319  0.000069  210.940860  210.940860
#
#               gr        tm.1     pre.1
# 0       0.000000  256.847377  0.000010
# 1       0.000000  260.237813  0.000016
# 2       0.000000  264.383167  0.000015
# 3      -0.000241  274.298624  0.000039
# 4  305771.217890  279.958319  0.000069
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     229 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 48.78038385932751
# Evaporation RMSE: 15.67842845728597
# nse_runoff: 0.6506736761451944 nse_ep: 0.979044267914779 kge_runoff: 0.8236563849137022 pbias_runoff: -4.984725310975934
# Runoff NSE: 0.6506736761451944
# Evaporation NSE: 0.9809240025554645
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         136.381348                5.369420
# 1     2000-02-01          57.520691                5.528300
# 2     2000-03-01          57.675137               25.204948
# 3     2000-04-01         121.022278              137.027481
# 4     2000-05-01         152.551346              208.342789
# ...          ...                ...                     ...
# 1207  2100-08-01         293.802216              267.296722
# 1208  2100-09-01         179.607513              257.475861
# 1209  2100-10-01         104.028976               93.816887
# 1210  2100-11-01          94.808075               55.978977
# 1211  2100-12-01          76.303429                0.963560
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp585
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   77.958065  256.847377  0.000010    3.899194    3.899194
# 1  2000-02-01   60.334483  260.237813  0.000016    6.876437    6.876437
# 2  2000-03-01   63.800000  264.383167  0.000015   30.002688   30.002688
# 3  2000-04-01  131.486667  274.298624  0.000039  135.943056  135.943056
# 4  2000-05-01  158.903226  279.958319  0.000069  210.940860  210.940860
#
#               gr        tm.1     pre.1
# 0       0.000000  256.847377  0.000010
# 1       0.000000  260.237813  0.000016
# 2       0.000000  264.383167  0.000015
# 3       0.000000  274.298624  0.000039
# 4  256103.864416  279.958319  0.000069
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     229 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 50.323140196833904
# Evaporation RMSE: 15.071855559871148
# nse_runoff: 0.6282282774730528 nse_ep: 0.9809240025554645 kge_runoff: 0.8131187370166904 pbias_runoff: -5.062536544127601
# Runoff NSE: 0.6282282774730528
# Evaporation NSE: 0.9823714884198282
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          85.933403                6.631987
# 1     2000-02-01          56.932827                5.906937
# 2     2000-03-01          56.173889               19.976404
# 3     2000-04-01         114.283821              138.862259
# 4     2000-05-01         155.902039              211.797775
# ...          ...                ...                     ...
# 1207  2100-08-01         174.485703              268.304901
# 1208  2100-09-01         158.471695              267.069489
# 1209  2100-10-01         161.639801              137.398941
# 1210  2100-11-01         106.473450               59.636761
# 1211  2100-12-01          92.334984               18.161409
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp126
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   23.290323  257.490499  0.000013   20.215054   20.215054
# 1  2000-02-01   25.310345  259.264650  0.000014   29.418391   29.418391
# 2  2000-03-01   24.396774  263.209690  0.000026   76.400000   76.400000
# 3  2000-04-01   29.353333  272.816659  0.000051  153.908889  153.908889
# 4  2000-05-01  125.874194  278.886187  0.000066  211.387097  211.387097
#
#              gr        tm.1     pre.1
# 0  0.000000e+00  257.490499  0.000013
# 1  0.000000e+00  259.264650  0.000014
# 2  0.000000e+00  263.209690  0.000026
# 3  6.894947e+01  272.816659  0.000051
# 4  2.248367e+06  278.886187  0.000066
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     190 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 105.17542967365884
# Evaporation RMSE: 13.554767655639054
# nse_runoff: 0.7567419434633001 nse_ep: 0.9823714884198282 kge_runoff: 0.7610771607961362 pbias_runoff: 4.771030627954923
# Runoff NSE: 0.7567419434633001
# Evaporation NSE: 0.9701132144900502
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         148.890198               15.624598
# 1     2000-02-01          29.876429               34.318157
# 2     2000-03-01          29.259491               72.529343
# 3     2000-04-01          37.542553              156.760681
# 4     2000-05-01         107.514389              201.861923
# ...          ...                ...                     ...
# 1207  2100-08-01         387.898956              193.418106
# 1208  2100-09-01         265.938873              146.441193
# 1209  2100-10-01          90.400131               80.325905
# 1210  2100-11-01          50.880779               35.891556
# 1211  2100-12-01          41.543419               17.811247
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp245
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   23.290323  257.490499  0.000013   20.215054   20.215054
# 1  2000-02-01   25.310345  259.264650  0.000014   29.418391   29.418391
# 2  2000-03-01   24.396774  263.209690  0.000026   76.400000   76.400000
# 3  2000-04-01   29.353333  272.816659  0.000051  153.908889  153.908889
# 4  2000-05-01  125.874194  278.886187  0.000066  211.387097  211.387097
#
#              gr        tm.1     pre.1
# 0  0.000000e+00  257.490499  0.000013
# 1  0.000000e+00  259.264650  0.000014
# 2  0.000000e+00  263.209690  0.000026
# 3  2.895661e+02  272.816659  0.000051
# 4  2.144599e+06  278.886187  0.000066
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     190 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 81.9550173818416
# Evaporation RMSE: 17.059116429743217
# nse_runoff: 0.8522968571673138 nse_ep: 0.9701132144900502 kge_runoff: 0.8271956945664172 pbias_runoff: 2.483585388694371
# Runoff NSE: 0.8522968571673138
# Evaporation NSE: 0.9526621948144334
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         175.450058               20.200516
# 1     2000-02-01          29.571503               34.248039
# 2     2000-03-01          29.571503               70.257896
# 3     2000-04-01          33.372868              155.304703
# 4     2000-05-01         117.578964              205.732651
# ...          ...                ...                     ...
# 1207  2100-08-01         397.746704              230.502289
# 1208  2100-09-01         273.515381              210.757980
# 1209  2100-10-01         109.524963              140.528564
# 1210  2100-11-01          86.556900               63.629196
# 1211  2100-12-01          38.253593               24.457064
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp370
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   23.290323  257.490499  0.000013   20.215054   20.215054
# 1  2000-02-01   25.310345  259.264650  0.000014   29.418391   29.418391
# 2  2000-03-01   24.396774  263.209690  0.000026   76.400000   76.400000
# 3  2000-04-01   29.353333  272.816659  0.000051  153.908889  153.908889
# 4  2000-05-01  125.874194  278.886187  0.000066  211.387097  211.387097
#
#              gr        tm.1     pre.1
# 0  0.000000e+00  257.490499  0.000013
# 1  0.000000e+00  259.264650  0.000014
# 2  0.000000e+00  263.209690  0.000026
# 3  1.607278e+02  272.816659  0.000051
# 4  2.110640e+06  278.886187  0.000066
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     190 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 98.18766030408541
# Evaporation RMSE: 20.630021362723337
# nse_runoff: 0.7879918942459686 nse_ep: 0.9526621948144334 kge_runoff: 0.7323051504515286 pbias_runoff: 5.967100316713271
# Runoff NSE: 0.7879918942459686
# Evaporation NSE: 0.9307699880135584
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         116.777199               19.414497
# 1     2000-02-01          29.784285               31.247562
# 2     2000-03-01          29.140959               69.001404
# 3     2000-04-01          36.535881              155.197083
# 4     2000-05-01         118.827309              207.969406
# ...          ...                ...                     ...
# 1207  2100-08-01         441.110260              242.999435
# 1208  2100-09-01         405.130127              229.681213
# 1209  2100-10-01         103.886169              173.273315
# 1210  2100-11-01          75.788475               77.581398
# 1211  2100-12-01          50.260540               16.256758
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp585
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   23.290323  257.490499  0.000013   20.215054   20.215054
# 1  2000-02-01   25.310345  259.264650  0.000014   29.418391   29.418391
# 2  2000-03-01   24.396774  263.209690  0.000026   76.400000   76.400000
# 3  2000-04-01   29.353333  272.816659  0.000051  153.908889  153.908889
# 4  2000-05-01  125.874194  278.886187  0.000066  211.387097  211.387097
#
#              gr        tm.1     pre.1
# 0  0.000000e+00  257.490499  0.000013
# 1  0.000000e+00  259.264650  0.000014
# 2  0.000000e+00  263.209690  0.000026
# 3  3.230608e+02  272.816659  0.000051
# 4  2.105247e+06  278.886187  0.000066
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     190 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 99.73644555794222
# Evaporation RMSE: 15.056839382043423
# nse_runoff: 0.7812508288617555 nse_ep: 0.9307699880135584 kge_runoff: 0.7358373296453071 pbias_runoff: 9.652022740642886
# Runoff NSE: 0.7812508288617555
# Evaporation NSE: 0.9631223968324885
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         109.507401               19.465265
# 1     2000-02-01          29.027723               36.206654
# 2     2000-03-01          28.790010               70.472504
# 3     2000-04-01          33.845356              156.464386
# 4     2000-05-01         124.490479              205.363434
# ...          ...                ...                     ...
# 1207  2100-08-01         336.711334              232.307266
# 1208  2100-09-01         361.635986              233.788422
# 1209  2100-10-01         200.127106              144.564926
# 1210  2100-11-01          82.184135               78.640106
# 1211  2100-12-01          51.445305               43.194874
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp126
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   22.422581  256.573928  0.000008    7.467186    7.467186
# 1  2000-02-01   18.693103  258.424701  0.000008   15.229489   15.229489
# 2  2000-03-01   17.961290  262.785065  0.000022   32.507230   32.507230
# 3  2000-04-01   69.780000  272.840859  0.000032  134.604598  134.604598
# 4  2000-05-01  165.990323  278.735648  0.000041  197.016685  197.016685
#
#               gr        tm.1     pre.1
# 0       0.000000  256.573928  0.000008
# 1       0.000000  258.424701  0.000008
# 2       0.000000  262.785065  0.000022
# 3       0.000000  272.840859  0.000032
# 4  630351.576588  278.735648  0.000041
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     190 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 46.39817351597371
# Evaporation RMSE: 19.638858958126868
# nse_runoff: 0.7675547723686691 nse_ep: 0.9631223968324885 kge_runoff: 0.7512711806763452 pbias_runoff: 11.860965311493024
# Runoff NSE: 0.7675547723686691
# Evaporation NSE: 0.9495592069082601
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          76.745239               15.361145
# 1     2000-02-01          21.590454               16.089190
# 2     2000-03-01          22.631540               31.310888
# 3     2000-04-01          75.594345              132.650589
# 4     2000-05-01         136.813477              188.885330
# ...          ...                ...                     ...
# 1207  2100-08-01         191.423065              202.771286
# 1208  2100-09-01         207.051559              140.936966
# 1209  2100-10-01          86.042015               51.940685
# 1210  2100-11-01          36.667290               14.604156
# 1211  2100-12-01          28.113226                8.125031
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp245
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   22.422581  256.573928  0.000008    7.467186    7.467186
# 1  2000-02-01   18.693103  258.424701  0.000008   15.229489   15.229489
# 2  2000-03-01   17.961290  262.785065  0.000022   32.507230   32.507230
# 3  2000-04-01   69.780000  272.840859  0.000032  134.604598  134.604598
# 4  2000-05-01  165.990323  278.735648  0.000041  197.016685  197.016685
#
#              gr        tm.1     pre.1
# 0       0.00000  256.573928  0.000008
# 1       0.00000  258.424701  0.000008
# 2       0.00000  262.785065  0.000022
# 3       0.00000  272.840859  0.000032
# 4  708687.73254  278.735648  0.000041
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     190 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 42.46728624186419
# Evaporation RMSE: 29.27708016065791
# nse_runoff: 0.8052722330694618 nse_ep: 0.9495592069082601 kge_runoff: 0.7637525060369608 pbias_runoff: 12.854244175966635
# Runoff NSE: 0.8052722330694618
# Evaporation NSE: 0.8879001767524787
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          87.542023               24.447489
# 1     2000-02-01          20.333456               13.912479
# 2     2000-03-01          23.215151               35.459595
# 3     2000-04-01          76.949562              132.056335
# 4     2000-05-01         162.032455              196.374939
# ...          ...                ...                     ...
# 1207  2100-08-01         188.727890              193.724869
# 1208  2100-09-01         218.443253              149.659775
# 1209  2100-10-01          92.553947               66.069298
# 1210  2100-11-01          50.022068               31.664757
# 1211  2100-12-01          32.429733                9.623986
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp370
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   22.422581  256.573928  0.000008    7.467186    7.467186
# 1  2000-02-01   18.693103  258.424701  0.000008   15.229489   15.229489
# 2  2000-03-01   17.961290  262.785065  0.000022   32.507230   32.507230
# 3  2000-04-01   69.780000  272.840859  0.000032  134.604598  134.604598
# 4  2000-05-01  165.990323  278.735648  0.000041  197.016685  197.016685
#
#               gr        tm.1     pre.1
# 0       0.000000  256.573928  0.000008
# 1       0.000000  258.424701  0.000008
# 2       0.000000  262.785065  0.000022
# 3       0.000000  272.840859  0.000032
# 4  583555.776872  278.735648  0.000041
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     190 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 56.795995214661154
# Evaporation RMSE: 18.64493837879583
# nse_runoff: 0.6516993439480484 nse_ep: 0.8879001767524787 kge_runoff: 0.6985244341971895 pbias_runoff: 15.296401229255881
# Runoff NSE: 0.6516993439480484
# Evaporation NSE: 0.9545356162373918
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          59.857601               28.414711
# 1     2000-02-01          21.385876               15.457029
# 2     2000-03-01          24.188717               34.628902
# 3     2000-04-01          77.578262              127.826233
# 4     2000-05-01         162.135834              193.752075
# ...          ...                ...                     ...
# 1207  2100-08-01         209.055832              194.819580
# 1208  2100-09-01         223.186600              182.004715
# 1209  2100-10-01          84.922020              168.815552
# 1210  2100-11-01          72.614639               76.749374
# 1211  2100-12-01          31.601681                3.141753
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp585
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   22.422581  256.573928  0.000008    7.467186    7.467186
# 1  2000-02-01   18.693103  258.424701  0.000008   15.229489   15.229489
# 2  2000-03-01   17.961290  262.785065  0.000022   32.507230   32.507230
# 3  2000-04-01   69.780000  272.840859  0.000032  134.604598  134.604598
# 4  2000-05-01  165.990323  278.735648  0.000041  197.016685  197.016685
#
#               gr        tm.1     pre.1
# 0       0.000000  256.573928  0.000008
# 1       0.000000  258.424701  0.000008
# 2       0.000000  262.785065  0.000022
# 3       0.000000  272.840859  0.000032
# 4  624470.187931  278.735648  0.000041
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     190 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 51.81027695720572
# Evaporation RMSE: 21.562804321393738
# nse_runoff: 0.7101650911858574 nse_ep: 0.9545356162373918 kge_runoff: 0.7389898074993595 pbias_runoff: 13.449070829974024
# Runoff NSE: 0.7101650911858574
# Evaporation NSE: 0.9391921164650591
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          69.779564               13.262693
# 1     2000-02-01          20.950638               15.174684
# 2     2000-03-01          20.883522               34.239090
# 3     2000-04-01          77.028091              130.641510
# 4     2000-05-01         169.762024              193.939285
# ...          ...                ...                     ...
# 1207  2100-08-01         218.103500              186.197067
# 1208  2100-09-01         230.679703              185.190750
# 1209  2100-10-01         126.618813              148.901276
# 1210  2100-11-01         109.880646               78.052841
# 1211  2100-12-01          49.526482               27.081545
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp126
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   47.022581  254.194203  0.000015   30.069522   30.069522
# 1  2000-02-01   46.275862  255.560030  0.000012   40.521998   40.521998
# 2  2000-03-01   42.861290  258.525700  0.000025   54.592881   54.592881
# 3  2000-04-01   42.706667  266.442870  0.000034   95.414368   95.414368
# 4  2000-05-01  126.374194  272.053629  0.000025  148.159622  148.159622
#
#             gr        tm.1     pre.1
# 0     0.000000  254.194203  0.000015
# 1     0.000000  255.560030  0.000012
# 2     0.000000  258.525700  0.000025
# 3     0.000000  266.442870  0.000034
# 4  3091.860226  272.053629  0.000025
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     232 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 153.23144142895794
# Evaporation RMSE: 19.920371069625784
# nse_runoff: 0.784253484887574 nse_ep: 0.9391921164650591 kge_runoff: 0.8665965993181759 pbias_runoff: 2.0672052621766226
# Runoff NSE: 0.784253484887574
# Evaporation NSE: 0.9151469488951036
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         199.849106               27.733553
# 1     2000-02-01          56.861099               51.371037
# 2     2000-03-01          56.772278               55.952457
# 3     2000-04-01          53.688580              107.444565
# 4     2000-05-01         115.254463              138.669495
# ...          ...                ...                     ...
# 1207  2100-08-01         566.761719              170.582092
# 1208  2100-09-01         393.923279              153.756119
# 1209  2100-10-01         123.160782               65.948090
# 1210  2100-11-01          81.047424               25.383684
# 1211  2100-12-01          63.255802               22.281509
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp245
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   47.022581  254.194203  0.000015   30.069522   30.069522
# 1  2000-02-01   46.275862  255.560030  0.000012   40.521998   40.521998
# 2  2000-03-01   42.861290  258.525700  0.000025   54.592881   54.592881
# 3  2000-04-01   42.706667  266.442870  0.000034   95.414368   95.414368
# 4  2000-05-01  126.374194  272.053629  0.000025  148.159622  148.159622
#
#             gr        tm.1     pre.1
# 0     0.000000  254.194203  0.000015
# 1     0.000000  255.560030  0.000012
# 2     0.000000  258.525700  0.000025
# 3     0.000000  266.442870  0.000034
# 4  1767.782002  272.053629  0.000025
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     232 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 131.41527192344307
# Evaporation RMSE: 20.156107167371314
# nse_runoff: 0.8413136059087047 nse_ep: 0.9151469488951036 kge_runoff: 0.8924096043002505 pbias_runoff: 7.2893622171490735
# Runoff NSE: 0.8413136059087047
# Evaporation NSE: 0.9131267773221066
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         153.654129               30.125671
# 1     2000-02-01          58.547688               46.175365
# 2     2000-03-01          59.318317               59.215569
# 3     2000-04-01          57.224350               99.204025
# 4     2000-05-01         107.151894              144.453598
# ...          ...                ...                     ...
# 1207  2100-08-01         649.639404              172.189835
# 1208  2100-09-01         336.997498              149.210098
# 1209  2100-10-01         126.840111               64.741425
# 1210  2100-11-01          91.192017               65.703705
# 1211  2100-12-01          75.115822               18.359640
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp370
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   47.022581  254.194203  0.000015   30.069522   30.069522
# 1  2000-02-01   46.275862  255.560030  0.000012   40.521998   40.521998
# 2  2000-03-01   42.861290  258.525700  0.000025   54.592881   54.592881
# 3  2000-04-01   42.706667  266.442870  0.000034   95.414368   95.414368
# 4  2000-05-01  126.374194  272.053629  0.000025  148.159622  148.159622
#
#             gr        tm.1     pre.1
# 0     0.000000  254.194203  0.000015
# 1     0.000000  255.560030  0.000012
# 2     0.000000  258.525700  0.000025
# 3     0.000000  266.442870  0.000034
# 4  4299.841256  272.053629  0.000025
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     232 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 128.08779536070148
# Evaporation RMSE: 20.899825862640828
# nse_runoff: 0.8492478492526716 nse_ep: 0.9131267773221066 kge_runoff: 0.9131912670882685 pbias_runoff: 4.45873614568292
# Runoff NSE: 0.8492478492526716
# Evaporation NSE: 0.9065976183943313
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         150.486526               22.400190
# 1     2000-02-01          55.734726               48.813213
# 2     2000-03-01          59.639114               62.854527
# 3     2000-04-01          52.494759              103.442474
# 4     2000-05-01         113.718155              142.446365
# ...          ...                ...                     ...
# 1207  2100-08-01         773.611511              172.593491
# 1208  2100-09-01         396.995026              160.969208
# 1209  2100-10-01         104.211205              111.005112
# 1210  2100-11-01         116.135414               60.805714
# 1211  2100-12-01          78.852699               47.643108
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp585
#          time         dis          tm       pre          ep        ep.1  \
# 0  2000-01-01   47.022581  254.194203  0.000015   30.069522   30.069522
# 1  2000-02-01   46.275862  255.560030  0.000012   40.521998   40.521998
# 2  2000-03-01   42.861290  258.525700  0.000025   54.592881   54.592881
# 3  2000-04-01   42.706667  266.442870  0.000034   95.414368   95.414368
# 4  2000-05-01  126.374194  272.053629  0.000025  148.159622  148.159622
#
#             gr        tm.1     pre.1
# 0     0.000000  254.194203  0.000015
# 1     0.000000  255.560030  0.000012
# 2     0.000000  258.525700  0.000025
# 3     0.000000  266.442870  0.000034
# 4  1944.712738  272.053629  0.000025
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     232 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 134.3141422455676
# Evaporation RMSE: 20.287616495129
# nse_runoff: 0.8342355101530545 nse_ep: 0.9065976183943313 kge_runoff: 0.893085070356938 pbias_runoff: 6.590691426513619
# Runoff NSE: 0.8342355101530545
# Evaporation NSE: 0.9119894635266532
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01         126.979004               32.033493
# 1     2000-02-01          57.556770               51.049999
# 2     2000-03-01          61.949909               61.400276
# 3     2000-04-01          60.310188              108.919365
# 4     2000-05-01         109.279480              137.278015
# ...          ...                ...                     ...
# 1207  2100-08-01         489.368042              188.260849
# ...
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# D:\Users\HP\miniconda3\envs\gpd_env\Lib\site-packages\pandas\plotting\_matplotlib\core.py:580: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# Runoff RMSE: 30.29556069284281
# Evaporation RMSE: 14.466683153182915
# nse_runoff: 0.8597011617786514 nse_ep: 0.8933866527036209 kge_runoff: 0.9128349841747638 pbias_runoff: 1.0582045687861803
# Runoff NSE: 0.8597011617786514
# Evaporation NSE: 0.9358469475947627
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          24.673233                9.637198
# 1     2000-02-01          22.351856               34.872391
# 2     2000-03-01          22.288462               37.516766
# 3     2000-04-01          43.925896               67.199425
# 4     2000-05-01          65.535332               98.813225
# ...          ...                ...                     ...
# 1207  2100-08-01         215.044006              127.763077
# 1208  2100-09-01          80.125412              103.246552
# 1209  2100-10-01          56.993519               74.846756
# 1210  2100-11-01          28.354765               24.909245
# 1211  2100-12-01          22.846714                9.447629
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp370
#          time  dis          tm       pre         ep       ep.1   gr  \
# 0  2000-01-01  NaN  252.271308  0.000008  13.436764  13.436764  0.0
# 1  2000-02-01  NaN  253.402941  0.000007  19.720854  19.720854  0.0
# 2  2000-03-01  NaN  256.364744  0.000015  39.709165  39.709165  0.0
# 3  2000-04-01  NaN  264.238010  0.000030  68.837037  68.837037  0.0
# 4  2000-05-01  NaN  269.998755  0.000028  86.756272  86.756272  0.0
#
#          tm.1     pre.1
# 0  252.271308  0.000008
# 1  253.402941  0.000007
# 2  256.364744  0.000015
# 3  264.238010  0.000030
# 4  269.998755  0.000028
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     252 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 34.82526363522386
# Evaporation RMSE: 16.292311527128984
# nse_runoff: 0.8146105947275506 nse_ep: 0.9358469475947627 kge_runoff: 0.8128372787363692 pbias_runoff: 7.191501067410138
# Runoff NSE: 0.8146105947275506
# Evaporation NSE: 0.9186336570453826
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          26.473812               11.058602
# 1     2000-02-01          24.606504               33.957989
# 2     2000-03-01          19.032143               37.981922
# 3     2000-04-01          45.159081               69.561737
# 4     2000-05-01          67.212692               90.177422
# ...          ...                ...                     ...
# 1207  2100-08-01         182.597473              153.053253
# 1208  2100-09-01         135.922089              153.501755
# 1209  2100-10-01          97.277504               80.812515
# 1210  2100-11-01          33.486622               23.962477
# 1211  2100-12-01          26.381327               17.822355
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp585
#          time  dis          tm       pre         ep       ep.1   gr  \
# 0  2000-01-01  NaN  252.271308  0.000008  13.436764  13.436764  0.0
# 1  2000-02-01  NaN  253.402941  0.000007  19.720854  19.720854  0.0
# 2  2000-03-01  NaN  256.364744  0.000015  39.709165  39.709165  0.0
# 3  2000-04-01  NaN  264.238010  0.000030  68.837037  68.837037  0.0
# 4  2000-05-01  NaN  269.998755  0.000028  86.756272  86.756272  0.0
#
#          tm.1     pre.1
# 0  252.271308  0.000008
# 1  253.402941  0.000007
# 2  256.364744  0.000015
# 3  264.238010  0.000030
# 4  269.998755  0.000028
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     252 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 29.880295480262603
# Evaporation RMSE: 16.99383803532651
# nse_runoff: 0.8635209907190805 nse_ep: 0.9186336570453826 kge_runoff: 0.8505860441598159 pbias_runoff: 6.934672913774275
# Runoff NSE: 0.8635209907190805
# Evaporation NSE: 0.9114757338867152
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          24.876438               11.839066
# 1     2000-02-01          23.007837               31.592346
# 2     2000-03-01          21.062185               39.501823
# 3     2000-04-01          46.470627               73.668533
# 4     2000-05-01          73.261154               95.364311
# ...          ...                ...                     ...
# 1207  2100-08-01         243.595947              103.863197
# 1208  2100-09-01         244.588165              122.179947
# 1209  2100-10-01         139.869705               85.737709
# 1210  2100-11-01          52.950321               45.931072
# 1211  2100-12-01          48.359238               62.242924
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp126
#          time        dis          tm       pre          ep        ep.1  \
# 0  2000-01-01  11.019677  258.116049  0.000008   17.158710   17.158710
# 1  2000-02-01   9.846207  259.777179  0.000006   30.532414   30.532414
# 2  2000-03-01  10.148387  263.034096  0.000016   54.243871   54.243871
# 3  2000-04-01  13.583333  272.202838  0.000027   90.959333   90.959333
# 4  2000-05-01  52.506452  278.296539  0.000032  132.774194  132.774194
#
#            gr        tm.1     pre.1
# 0     0.00000  258.116049  0.000008
# 1     0.00000  259.777179  0.000006
# 2     0.00000  263.034096  0.000016
# 3     0.00000  272.202838  0.000027
# 4  5769.03072  278.296539  0.000032
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     276 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 58.73700781358042
# Evaporation RMSE: 16.998873055009906
# nse_runoff: 0.7518804294940904 nse_ep: 0.9114757338867152 kge_runoff: 0.8064406391833492 pbias_runoff: 2.74969530424342
# Runoff NSE: 0.7518804294940904
# Evaporation NSE: 0.9169844065885931
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          43.460114               40.987377
# 1     2000-02-01          12.365095               33.852711
# 2     2000-03-01          12.365095               58.937252
# 3     2000-04-01          15.487621               88.621376
# 4     2000-05-01          37.240761              136.273880
# ...          ...                ...                     ...
# 1207  2100-08-01         327.757690              168.829025
# 1208  2100-09-01         141.339951              130.516968
# 1209  2100-10-01          23.560280               64.111313
# 1210  2100-11-01          15.160122               28.376154
# 1211  2100-12-01          12.365095               13.306049
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp245
#          time        dis          tm       pre          ep        ep.1  \
# 0  2000-01-01  11.019677  258.116049  0.000008   17.158710   17.158710
# 1  2000-02-01   9.846207  259.777179  0.000006   30.532414   30.532414
# 2  2000-03-01  10.148387  263.034096  0.000016   54.243871   54.243871
# 3  2000-04-01  13.583333  272.202838  0.000027   90.959333   90.959333
# 4  2000-05-01  52.506452  278.296539  0.000032  132.774194  132.774194
#
#             gr        tm.1     pre.1
# 0     0.000000  258.116049  0.000008
# 1     0.000000  259.777179  0.000006
# 2     0.000000  263.034096  0.000016
# 3     0.000000  272.202838  0.000027
# 4  6330.880848  278.296539  0.000032
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     276 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 61.11790176182409
# Evaporation RMSE: 13.626534261737408
# nse_runoff: 0.7313577878068522 nse_ep: 0.9169844065885931 kge_runoff: 0.8074159490240882 pbias_runoff: -0.43341423401423235
# Runoff NSE: 0.7313577878068522
# Evaporation NSE: 0.9466554273380844
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          89.250191               24.648430
# 1     2000-02-01          12.053199               31.036392
# 2     2000-03-01          11.914917               53.273796
# 3     2000-04-01          14.814623               89.239449
# 4     2000-05-01          37.867790              136.623016
# ...          ...                ...                     ...
# 1207  2100-08-01         349.956024              134.147751
# 1208  2100-09-01         149.312134              120.264000
# 1209  2100-10-01          19.564518               59.408432
# 1210  2100-11-01          20.147547               45.299515
# 1211  2100-12-01          15.639017               14.300954
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp370
#          time        dis          tm       pre          ep        ep.1  \
# 0  2000-01-01  11.019677  258.116049  0.000008   17.158710   17.158710
# 1  2000-02-01   9.846207  259.777179  0.000006   30.532414   30.532414
# 2  2000-03-01  10.148387  263.034096  0.000016   54.243871   54.243871
# 3  2000-04-01  13.583333  272.202838  0.000027   90.959333   90.959333
# 4  2000-05-01  52.506452  278.296539  0.000032  132.774194  132.774194
#
#             gr        tm.1     pre.1
# 0     0.000000  258.116049  0.000008
# 1     0.000000  259.777179  0.000006
# 2     0.000000  263.034096  0.000016
# 3     0.000000  272.202838  0.000027
# 4  6926.208693  278.296539  0.000032
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     276 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 50.81329844183858
# Evaporation RMSE: 11.622054852064206
# nse_runoff: 0.8143084431848372 nse_ep: 0.9466554273380844 kge_runoff: 0.871161815350133 pbias_runoff: -1.6577665464657312
# Runoff NSE: 0.8143084431848372
# Evaporation NSE: 0.9611952171928848
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          22.662951               23.682079
# 1     2000-02-01          12.297381               30.845741
# 2     2000-03-01          12.297381               53.581406
# 3     2000-04-01          16.187548               88.528168
# 4     2000-05-01          45.613552              132.737000
# ...          ...                ...                     ...
# 1207  2100-08-01         237.088196              170.939285
# 1208  2100-09-01         295.996582              147.854065
# 1209  2100-10-01          26.885540              128.383102
# 1210  2100-11-01          22.413099               51.643169
# 1211  2100-12-01          17.056379               19.039898
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []
# ssp585
#          time        dis          tm       pre          ep        ep.1  \
# 0  2000-01-01  11.019677  258.116049  0.000008   17.158710   17.158710
# 1  2000-02-01   9.846207  259.777179  0.000006   30.532414   30.532414
# 2  2000-03-01  10.148387  263.034096  0.000016   54.243871   54.243871
# 3  2000-04-01  13.583333  272.202838  0.000027   90.959333   90.959333
# 4  2000-05-01  52.506452  278.296539  0.000032  132.774194  132.774194
#
#            gr        tm.1     pre.1
# 0     0.00000  258.116049  0.000008
# 1     0.00000  259.777179  0.000006
# 2     0.00000  263.034096  0.000016
# 3     0.00000  272.202838  0.000027
# 4  4824.61274  278.296539  0.000032
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1212 non-null   object
#  1   dis     276 non-null    float64
#  2   tm      1212 non-null   float64
#  3   pre     1212 non-null   float64
#  4   ep      252 non-null    float64
#  5   ep.1    252 non-null    float64
#  6   gr      1212 non-null   float64
#  7   tm.1    1212 non-null   float64
#  8   pre.1   1212 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 85.3+ KB
# None
# Runoff RMSE: 58.097740862033724
# Evaporation RMSE: 12.483197341950053
# nse_runoff: 0.7572518810685349 nse_ep: 0.9611952171928848 kge_runoff: 0.8120369641243574 pbias_runoff: 1.8208199261965283
# Runoff NSE: 0.7572518810685349
# Evaporation NSE: 0.9552316500498582
#             time  runoff_projection  evaporation_projection
# 0     2000-01-01          50.850456               25.702719
# 1     2000-02-01          12.454554               32.114269
# 2     2000-03-01          12.454554               57.334076
# 3     2000-04-01          15.923878               88.907501
# 4     2000-05-01          38.694286              135.962189
# ...          ...                ...                     ...
# 1207  2100-08-01         380.090942              167.108612
# 1208  2100-09-01         332.668579              156.147049
# 1209  2100-10-01          86.978546              128.484985
# 1210  2100-11-01          27.165133              101.088638
# 1211  2100-12-01          16.253412               80.248634
#
# [1212 rows x 3 columns]
# Empty DataFrame
# Columns: [dis, tm, pre, ep, ep.1, gr, tm.1, pre.1, pre_lag1, tm_lag1, gr_lag1, runoff_projection, evaporation_projection]
# Index: []

# %%
combined_data

# %%
data

# %%
data = pd.read_csv(file_path)
# Example of adding a 1-month lag
data['pre_lag1'] = data['pre'].shift(1)
data['tm_lag1'] = data['tm'].shift(1)
data['mb_lag1'] = data['gr'].shift(1)
future_data = data[data['dis'].isna()] 
# Prepare future data inputs for the model (remove 'dis' column if it exists)
X_future = future_data[['pre', 'tm', 'gr', 'pre_lag1', 'tm_lag1', 'mb_lag1']]
future_data

# %%
X_future

# %%
# Predict runoff for future periods
future_data['runoff_projection'] = model.predict(X_future)
print(future_data[['time', 'runoff_projection']])  # Display future projections

# %%
# Concatenate historical and future data
historic_data = data.dropna()
combined_data = pd.concat([historic_data, future_data])
# Convert the 'time' column to datetime format, matching the format of your data
combined_data['time'] = pd.to_datetime(combined_data['time'], format='%Y/%m/%d', errors='coerce')

# Drop any rows where 'time' couldn't be parsed (if there are invalid dates)
combined_data = combined_data.dropna(subset=['time'])

# Set 'time' as the index
combined_data.set_index('time', inplace=True)

# Display the updated DataFrame with 'time' as the index
print(combined_data.head())

# %%
combined_data[['dis','runoff_projection']].plot()

# %%
annual_data = combined_data[['dis','runoff_projection']].resample('Y').sum()

# %%
annual_data.plot()
